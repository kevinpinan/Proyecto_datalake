# %%
import couchdb
import tweepy
import json

###API ########################
ckey = "oHPnhtrKHK6GFlV57pdER7GEI"
csecret = "bG2PWWAwTyqXln3WSemte9W334qsGsO10QIjgVwM8Kq6bAnWSn"
atoken = "1340075672086130688-T2QpAtisN6EsduN4m8s0NZ8rc49ulj"
asecret = "HevHRl52FT4Dv4G6GrFkVsGpQiDgNYHMCZAKT9eb5937M"
#####################################
##
class listener(tweepy.Stream):    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
twitter_stream = listener(ckey, csecret,atoken,asecret)


'''========couchdb'=========='''
server = couchdb.Server('http://kevin:Kevin1994@localhost:5984/')
try:
    #db = server.create('pulso_politica-twitter')
    db = server.create('juego')
except:
    #db = server['pulso_politica-twitter']
    db = server['juego']
    

# @ZelenskyyUa UCRANIA
# condemn China f CHINA
# @AndrzejDuda POLONIA
# Panama-registrered PANAMA
# @niinisto FINLANDIA
# @KlausIohannis RUMANIA
# @JoeBiden EEUU
# @jairbolsonaro BRASIL
# Argentina y ARGENTINA
# @NicolasMaduro VENEZUELA
# @ChefSteinmeier ALEMANIA
# @HassanRouhani IRAN
# @MinskBielorusia bielorusia
# @KremlinRussiaVP    RUSIA
# @Presidencia_Ec   ECUADOR
# @BorisJohnson INGLATERRA
# @lopezobrador_    MEXICO
# @IvanDuque   COLOMBIA
# @kishida230 JAPON
# @EmmanuelMacron FRANCIA
twitter_stream.filter(track=['@ZelenskyyUa'])
# Out:
# SAVED('1497477161883627524', '1-248b68bf2e7585193101a4d3cd2c5dea')=>b'{"created_at":"Sat Feb 26 07:42:31 +0000 2022","id":1497477161883627524,"id_str":"1497477161883627524","text":"RT @DavidYankovich: \\u201cThis may be the last time you see me alive.\\u201d-@ZelenskyyUa, 02\\/25\\/2022. https:\\/\\/t.co\\/RXyxXozfno","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":224432668,"id_str":"224432668","name":"Arel \\u264d\\ufe0e","screen_name":"virgoshawtyyyy","location":"California, USA","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":1295,"friends_count":561,"listed_count":4,"favourites_count":33323,"statuses_count":51902,"created_at":"Thu Dec 09 00:27:08 +0000 20
# ...

# %%
# Out:
# SAVED('1497447348762558466', '1-ab2660f2951668caad2e694a34a86d00')=>b'{"created_at":"Sat Feb 26 05:44:03 +0000 2022","id":1497447348762558466,"id_str":"1497447348762558466","text":"RT @AlertaNews24UKR: \\ud83c\\uddf7\\ud83c\\uddfa\\ud83c\\uddfa\\ud83c\\udde6 | El ej\\u00e9rcito ucraniano logra dar su primer golpe fuera de Ucrania, han atacado una base militar rusa en Millerov\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1027616683341623298,"id_str":"1027616683341623298","name":"El Se\\u00f1or de las Bolsas.\\ud83d\\udcb0","screen_name":"ElAraquese93","location":"C\\u00facuta, Colombia","url":null,"description":"https:\\/\\/www.instagram.com\\/DiegoAraque93\\/\\nAl fondo a la derecha.","translator_type":"no
# ...

# %%
import requests
from pymongo import MongoClient
import couchdb

# %%
###################TRASPASO LOS DATOS## DE COUCH A MONGOO#####################


########################TRASPASO DE COUCH A MONGO

#Establecer el direccionamiento de nuestro CouchDB
##pip install --user -U pymongo

#!/usr/bin/env python
# coding: utf-8

# In[2]:


#Librerias
import requests
from pymongo import MongoClient
import couchdb


# In[3]:


#Establecer el direccionamiento de nuestro CouchDB
URL = 'http://kevin:Kevin1994@127.0.0.1:5984'
print(URL)


#Verificacion de la conexion con CouchDB
try:
    response = requests.get(URL)
    if response.status_code == 200:
        print('CouchDB connection: Success')
    if response.status_code == 401:
        print('CouchDB connection: failed', response.json())
except requests.ConnectionError as e:
    raise e
    
#Establecer los parametros que recibira la base de datos
server=couchdb.Server(URL)

HEADERS = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}


db = server["juego"]  #COUCH

#conexion con mongodb
client = MongoClient("mongodb://localhost:27017")
try:
    client.admin.command("ismaster")
    print("MongoDB connection: Success")
except ConnectionFailure as cf:
    print("MongoDB connection: Failed", cf)

dbs = client.juegos

db_one = dbs.tweet_collection

#for que permite el traspaso de datos
for id in db:
    if(db_one.find_one({"_id" : db[id].id})):
        print("This id of the document already exist")
    else:
        db_one.insert_one(db[id])


# In[ ]:
# Out:
# http://kevin:Kevin1994@127.0.0.1:5984
# CouchDB connection: Success
# MongoDB connection: Success

# %%
#PRUEBAS
import couchdb
import tweepy
import json

###API ########################
ckey = "oHPnhtrKHK6GFlV57pdER7GEI"
csecret = "bG2PWWAwTyqXln3WSemte9W334qsGsO10QIjgVwM8Kq6bAnWSn"
atoken = "1340075672086130688-T2QpAtisN6EsduN4m8s0NZ8rc49ulj"
asecret = "HevHRl52FT4Dv4G6GrFkVsGpQiDgNYHMCZAKT9eb5937M"
#####################################
class listener(tweepy.Stream):    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
twitter_stream = listener(ckey, csecret,atoken,asecret)


'''========couchdb'=========='''
server = couchdb.Server('http://kevin:Kevin1994@localhost:5984/')
try:
    db = server.create('pulso_politica-twitter')
    #db = server.create('pruebas')
except:
    db = server['pulso_politica-twitter']
    #db = server['pruebas']
    

# @ZelenskyyUa UCRANIA
# condemn China f CHINA
# @AndrzejDuda POLONIA
# Panama-registrered PANAMA
# @niinisto FINLANDIA
# @KlausIohannis RUMANIA
# @JoeBiden EEUU
# @jairbolsonaro BRASIL
# Argentina y ARGENTINA
# @NicolasMaduro VENEZUELA
# @ChefSteinmeier ALEMANIA
# @HassanRouhani IRAN
# @MinskBielorusia bielorusia
# @KremlinRussiaVP    RUSIA
# @Presidencia_Ec   ECUADOR
# @BorisJohnson INGLATERRA
# @lopezobrador_    MEXICO
# @IvanDuque   COLOMBIA
# @kishida230 JAPON
# @EmmanuelMacron FRANCIA
twitter_stream.filter(track=['Alemania'])
